# %%
# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py

def load_vector_appended(filename, dataset_name):

    with h5py.File(filename, 'r') as f:
        data = f[dataset_name][:]
        print(f"Loaded dataset '{dataset_name}' with shapes {data.shape}")
    return data

file = 'CSTR_SimulationData.h5'

Time = load_vector_appended(file, 'Time')
C_A = load_vector_appended(file, 'C_A')  #1
T = load_vector_appended(file, 'T')  #2
T_C = load_vector_appended(file, 'T_C')  #3
h = load_vector_appended(file, 'h')  #4
Q_SP = load_vector_appended(file, 'Q_SP')  #5
Qc_SP = load_vector_appended(file, 'Qc_SP')  #6
l = load_vector_appended(file, 'l')  #7
l_c = load_vector_appended(file, 'l_c')  #8
Q = load_vector_appended(file, 'Q_vec')  #9
Q_c = load_vector_appended(file, 'Q_c_vec')  #10

file = 'CSTR_InputVectors.h5'

E_R = load_vector_appended(file, 'F1')[1:]
U_Ac = load_vector_appended(file, 'F2')[1:]
T_bias = load_vector_appended(file, 'F3')[1:]
T_F = load_vector_appended(file, 'F4')[1:]   #14
C_AF = load_vector_appended(file, 'F5')[1:]  #11
T_CF = load_vector_appended(file, 'F6')[1:]  #12
Q_F = load_vector_appended(file, 'F7')[1:]  #13
dP = load_vector_appended(file, 'F8')[1:]
dPc = load_vector_appended(file, 'F9')[1:]


plot_var = E_R
plot_var_name = r"E/R (K)"

#averages
C_A_avg = np.mean(C_A)
T_avg = np.mean(T)
T_C_avg = np.mean(T_C)
h_avg = np.mean(h)
Q_SP_avg = np.mean(Q_SP)
Qc_SP_avg = np.mean(Qc_SP)
l_avg = np.mean(l)
l_c_avg = np.mean(l_c)
Q_avg = np.mean(Q)
Q_c_avg = np.mean(Q_c)


# Print averages
print(f"C_A_avg: {C_A_avg:.4f}")
print(f"T_avg: {T_avg:.4f}")
print(f"T_C_avg: {T_C_avg:.4f}")
print(f"h_avg: {h_avg:.4f}")
print(f"Q_SP_avg: {Q_SP_avg:.4f}")
print(f"Qc_SP_avg: {Qc_SP_avg:.4f}")
print(f"l_avg: {l_avg:.4f}")
print(f"l_c_avg: {l_c_avg:.4f}")
print(f"Q_avg: {Q_avg:.4f}")
print(f"Q_c_avg: {Q_c_avg:.4f}")


# %%
# Plotting

plt.figure(figsize=(8, 4))
Time = Time / 3600

plt.plot(Time, plot_var)
plt.xlabel('Time (h)')
plt.ylabel(plot_var_name)

plt.figure(figsize=(12, 10))

plt.subplot(3, 2, 1)
plt.plot(Time, C_A)
plt.xlabel('Time (h)')
plt.ylabel('$C_{A}$ (mol/L)')

plt.subplot(3, 2, 2)
plt.plot(Time, h)
plt.xlabel('Time (h)')
plt.ylabel('H (m)')

plt.subplot(3, 2, 3)
plt.plot(Time, T)
plt.xlabel('Time (h)')
plt.ylabel('T (K)')

plt.subplot(3, 2, 4)
plt.plot(Time, T_C)
plt.xlabel('Time (h)')
plt.ylabel('$T_{C}$ (K)')

plt.subplot(3, 2, 5)
plt.plot(Time, Q)
plt.xlabel('Time (h)')
plt.ylabel('Q (L/s)')

plt.subplot(3, 2, 6)
plt.plot(Time, Q_c)
plt.xlabel('Time (h)')
plt.ylabel('$Q_{c}$ (L/s)')


# %%
# Plot numbered vectors above
plt.figure(figsize=(14, 12))
plt.subplot(7, 2, 1)
plt.plot(Time, C_A, color = 'black')
plt.xlabel('Time (h)')
plt.ylabel('$C_{A}$ (mol/L)')

plt.subplot(7, 2, 2)
plt.plot(Time, T, color = 'black')
plt.xlabel('Time (h)')
plt.ylabel('$T$ (K)')

plt.subplot(7, 2, 3)
plt.plot(Time, T_C, color = 'black')
plt.xlabel('Time (h)')
plt.ylabel('$T_{C}$ (K)')

plt.subplot(7, 2, 4)
plt.plot(Time, h, color = 'black')
plt.xlabel('Time (h)')
plt.ylabel('$H$ (m)')

plt.subplot(7, 2, 5)
plt.plot(Time, Q_SP, color = 'black')
plt.xlabel('Time (h)')
plt.ylabel('$Q_{SP}$ (L/s)')

plt.subplot(7, 2, 6)
plt.plot(Time, Qc_SP, color = 'black')
plt.xlabel('Time (h)')
plt.ylabel('$Q_{C,SP}$ (L/s)')

plt.subplot(7, 2, 7)
plt.plot(Time, l, color = 'black')
plt.xlabel('Time (h)')
plt.ylabel('$l$ (% Open)')

plt.subplot(7, 2, 8)
plt.plot(Time, l_c, color = 'black')
plt.xlabel('Time (h)')
plt.ylabel('$l_{C}$ (% Open)')

plt.subplot(7, 2, 9)
plt.plot(Time, Q, color = 'black')
plt.xlabel('Time (h)')
plt.ylabel('$Q$ (L/s)')

plt.subplot(7, 2, 10)
plt.plot(Time, Q_c, color = 'black')
plt.xlabel('Time (h)')
plt.ylabel('$Q_{C}$ (L/s)')

plt.subplot(7, 2, 11)
plt.plot(Time, T_F, color = 'black')
plt.xlabel('Time (h)')
plt.ylabel('$T_{F}$ (K)')

plt.subplot(7, 2, 12)
plt.plot(Time, C_AF, color = 'black')
plt.xlabel('Time (h)')
plt.ylabel('$C_{A,F}$ (mol/L)')

plt.subplot(7, 2, 13)
plt.plot(Time, T_CF, color = 'black')
plt.xlabel('Time (h)')
plt.ylabel('$T_{C,F}$ (K)')

plt.subplot(7, 2, 14)
plt.plot(Time, Q_F, color = 'black')
plt.xlabel('Time (h)')
plt.ylabel('$Q_{F}$ (L/s)')
# Out:
# Loaded dataset 'Time' with shapes (99999, 1)
# Loaded dataset 'C_A' with shapes (99999, 1)
# Loaded dataset 'T' with shapes (99999, 1)
# Loaded dataset 'T_C' with shapes (99999, 1)
# Loaded dataset 'h' with shapes (99999, 1)
# Loaded dataset 'Q_SP' with shapes (99999, 1)
# Loaded dataset 'Qc_SP' with shapes (99999, 1)
# Loaded dataset 'l' with shapes (99999, 1)
# Loaded dataset 'l_c' with shapes (99999, 1)
# Loaded dataset 'Q_vec' with shapes (99999, 1)
# Loaded dataset 'Q_c_vec' with shapes (99999, 1)
# Loaded dataset 'F1' with shapes (100000, 1)
# Loaded dataset 'F2' with shapes (100000, 1)
# Loaded dataset 'F3' with shapes (100000, 1)
# Loaded dataset 'F4' with shapes (100000, 1)
# Loaded dataset 'F5' with shapes (100000, 1)
# Loaded dataset 'F6' with shapes (100000, 1)
# Loaded dataset 'F7' with shapes (100000, 1)
# Loaded dataset 'F8' with shapes (100000, 1)
# Loaded dataset 'F9' with shapes (100000, 1)
# C_A_avg: 0.0394
# T_avg: 401.7030
# T_C_avg: 344.2712
# h_avg: 0.6000
# Q_SP_avg: 1.6662
# Qc_SP_avg: 0.2663
# l_avg: 0.5004
# l_c_avg: 0.5327
# Q_avg: 1.6662
# Q_c_avg: 0.2663
# Text(0, 0.5, '$Q_{F}$ (L/s)')
# Matplotlib is building the font cache; this may take a moment.
